# %% [markdown]
# **BÀI 1** Khai báo hàm init

# %%
class TeamA:
    def __init__(self,name,age):
        self.__x=name #private nên không lấy ra trực tiếp được
        self.__y=age
    def get_name(self):#hàm lấy name ra
        return self.__x
s=TeamA("qnhu",18)
print(s.get_name()) #in ra name thông qua hàm get_name
# Out:
# qnhu

# %% [markdown]
# **BÀI 2** Tùy chỉnh hàm theo ý muốn

# %%
class TeamA:
    def __init__(self,name,age):
        self.__x=name #private nên không lấy ra trực tiếp được
        self.__y=age
    def get_name(self):#hàm lấy name ra
        return self.__x
    def set_name(self,name):#hàm tự chỉnh name
        self.__x=name
s=TeamA("qnhu",18)
s.blood="B"#thêm thuộc tính 
s.set_name("quynhnhu") #chỉnh name theo ý muốn
print(s.blood) #in ra name đã chỉnh thông qua hàm get_name
# Out:
# B
